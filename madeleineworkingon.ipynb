# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
fuel_csv = Path("Resources/Dist Fuel Pricing 2019-2023.csv")
fuel_df = pd.read_csv(fuel_csv)
fuel_df.head()
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2 PRICE FLUCTUATIONS                     \
# 0         NaN        NaN        NaN                                   NaN
# 1        DATE     Brent     Up/Down                                 Tapis
# 2         NaN        NaN        NaN                                   NaN
# 3  31/12/2023      77.04       0.00                                 78.67
# 4  30/12/2023      77.04      -1.35                                 81.48
#
#   Unnamed: 4       01-Jan-23 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0        NaN             NaN        NaN        NaN        NaN        NaN
# 1    Up/Down  Exchange Rate     Up/Down     CHANGE   VIVA TGP         BP
# 2        NaN             NaN        NaN        NaN        NaN        NaN
# 3     -2.81            68.12     -0.02        0.02     174.20     171.43
# 4     -2.41            68.14     -0.21       -1.14     174.20     171.43
#
#   Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13  Unnamed: 14 Unnamed: 15  \
# ...

# %%
#clean data 
fuel_dropcol=fuel_df.drop(columns=['Unnamed: 4','Unnamed: 7','Unnamed: 12','Unnamed: 13','Unnamed: 14', 'Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18'])
fuel_dropnan=fuel_dropcol.dropna()

fuel_clean=fuel_dropnan.rename(columns={"Unnamed: 0": "Date", "Unnamed: 1": "Brent $","Unnamed: 2": "Brent Movement","Unnamed: 4":"Tapis Movement",
                                         "PRICE FLUCTUATIONS": "Tapis","01-Jan-23": "Exchange Rate","Unnamed: 6": "Exchange rate movement","Unnamed: 8": "Viva",
                                         "Unnamed: 9": "BP","Unnamed: 10": "Caltex","Unnamed: 11": "Mobil"})

fuel_clean
# Out:
#             Date Brent $ Brent Movement PRICE FLUCTUATIONS                     \
# 1           DATE  Brent         Up/Down                                 Tapis
# 3     31/12/2023   77.04           0.00                                 78.67
# 4     30/12/2023   77.04          -1.35                                 81.48
# 5     29/12/2023   78.39          -1.24                                 83.89
# 6     28/12/2023   79.63          -1.24                                 82.37
# ...          ...     ...            ...                                   ...
# 1338  27/05/2020   34.35           1.10                                 33.42
# 1339  28/05/2020   32.81          -1.54                                 33.59
# 1340  29/05/2020   33.71           0.90                                 32.33
# 1341  30/05/2020   35.49           1.78                                 34.09
# 1342  31/05/2020   35.49           0.00                                 34.09
#
# ...

# %%
fuel_clean["Viva"].unique()
# Out:
# array(['VIVA TGP', '174.20', '174.78', '175.09', '175.02', '175.00',
#        '174.63', '173.61', '173.90', '173.89', '174.02', '174.98',
#        '174.87', '174.66', '175.33', '176.06', '177.44', '178.08',
#        '179.08', '179.77', '179.71', '180.51', '181.27', '181.54',
#        '180.93', '181.14', '180.76', '181.43', '181.37', '181.82',
#        '181.47', '181.92', '182.36', '184.25', '187.11', '189.67',
#        '191.62', '192.85', '193.91', '194.68', '195.67', '195.88',
#        '197.07', '198.73', '199.82', '200.28', '201.85', '202.72',
#        '203.38', '203.23', '202.02', '200.74', '199.27', '197.32',
#        '197.23', '198.45', '200.67', '203.07', '206.50', '209.46',
#        '210.11', '209.13', '209.20', '208.34', '207.98', '208.40',
#        '208.51', '209.23', '209.76', '210.18', '210.57', '210.21',
#        '208.75', '207.53', '207.02', '205.57', '204.09', '202.18',
#        '200.71', '199.67', '199.66', '201.20', '201.15', '200.87',
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 null_values = fuel_sort['Viva'].isnull().sum()
#       2 print("Number of missing values in 'Viva' column:", null_values)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# Assuming you have a DataFrame called 'df' with columns 'Date' and 'Value'
# 'Date' column contains the dates and 'Value' column contains the data you want to calculate the movement for

# Sort the DataFrame by date in ascending order
fuel_sort=fuel_clean.sort_values(by=['Date'], inplace=True, ascending=False)
fuel_sort

# %%
# Create a new colunm called 'Movement' to store the calculated movements

fuel_sort['Movement'] = fuel_sort['Viva'].diff()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Create a new colunm called 'Movement' to store the calculated movements
# ----> 2 fuel_sort['Movement'] = fuel_sort['Viva'].diff()
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# Print the DataFrame to see the results
print(fuel_clean)
# Out:
#            Date Brent $ Brent Movement PRICE FLUCTUATIONS                     \
# 1          DATE  Brent         Up/Down                                 Tapis
# 25    9/12/2023   75.84           1.59                                 79.66
# 376   9/12/2022   76.25          -0.98                                 84.82
# 1106  9/12/2020   45.63          -0.02                                 48.61
# 55    9/11/2023   79.76          -1.65                                 88.71
# ...         ...     ...            ...                                   ...
# 674   1/02/2022   88.04           1.22                                 93.40
# 1039  1/02/2021   52.20           0.06                                 54.93
# 367   1/01/2023   85.91           0.00                                 85.92
# 702   1/01/2022   75.41          -1.07                                 83.25
# 1067  1/01/2021   48.45           0.14                                 52.13
#
# ...

# %%
fuel_clean.insert(12, "Age", [viva_movement], True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 fuel_clean.insert(12, "Age", [], True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4776, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    4773 if not isinstance(loc, int):
#    4774     raise TypeError("loc must be int")
# -> 4776 value = self._sanitize_column(value)
#    4777 self._mgr.insert(loc, column, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4870, in DataFrame._sanitize_column(self, value)
#    4867     return _reindex_for_setitem(Series(value), self.index)
#    4869 if is_list_like(value):
# -> 4870     com.require_length_match(value, self.index)
#    4871 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\common.py:576, in require_length_match(data, index)
# ...

# %%
#create loop to find movement between previous day and current day 

Monthly_changes=[]
Prev_profit=0 


for row in fuel_clean:
        Date.append(row[0])
        Viva.append(int(row[1]))
        if len(Date) == 1:
            Monthly_changes.append(0)
        else:
            current_change = int(row[1])-Prev_profit
            Monthly_changes.append(current_change)
        Prev_profit = int(row[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 8
#       4 Prev_profit=0
#       7 for row in fuel_clean:
# ----> 8         Date.append(row[0])
#       9         Viva.append(int(row[1]))
#      10         if len(Date) == 1:
#
# NameError: name 'Date' is not defined

# %%
#GET AVERAGE MOVEMENT  BY MONTH 

#Average =sum(Monthly_changes)/(total_months-1)

# %%
#GET AVERAGE MOVEMENT BY YEAR
