# %%
import requests

import json

# %%
api_url = "https://api.data.abs.gov.au/datastructure/ABS?detail=allstubs"

# %%
response = requests.get(api_url)

response
# Out:
# <Response [200]>

# %%
headers = {
    'accept': 'application/vnd.sdmx.structure+json',
    'x-api-key': 'Hfy2l7nNS64nFxMsk7drl8aNk7NF5rYb3XxbrVGB',  
}


response = requests.get(api_url, headers=headers)

print(json.dumps(response.json(), indent=4, sort_keys=True))
# Out:
# {
#     "data": {
#         "dataStructures": [
#             {
#                 "agencyID": "ABS",
#                 "dataStructureComponents": {},
#                 "id": "ABORIGINAL_POP_PROJ",
#                 "isExternalReference": true,
#                 "isFinal": true,
#                 "links": [
#                     {
#                         "href": "https://api-reg.data.abs.gov.au/DisseminateNSIService/rest/datastructure/ABS/ABORIGINAL_POP_PROJ/1.0.0",
#                         "rel": "external"
#                     }
#                 ],
#                 "name": "Projected population, Aboriginal and Torres Strait Islander Australians, Australia, state and territories, 2016 to 2031",
#                 "names": {
#                     "en": "Projected population, Aboriginal and Torres Strait Islander Australians, Australia, state and territories, 2016 to 2031"
#                 },
#                 "version": "1.0.0"
#             },
#             {
# ...
